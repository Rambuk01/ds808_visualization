# %%
import pandas as pd
nd = pd.read_csv('archive/listings_cleaned.csv', sep=',', encoding='utf-8')

# %%
# Out:
#              id neighbourhood_cleansed  latitude  longitude        room_type  \
# 61       495934                  Valby  55.66613   12.49663  Entire home/apt
# 137      313003               Indre By  55.68409   12.56349  Entire home/apt
# 197      391758               Nørrebro  55.69966   12.54517  Entire home/apt
# 203      888702               Nørrebro  55.68536   12.55688  Entire home/apt
# 209      432409               Indre By  55.68189   12.57498  Entire home/apt
# ...         ...                    ...       ...        ...              ...
# 12181  53291562             Amager Øst  55.63731   12.62533     Private room
# 12251  53564610         Brønshøj-Husum  55.74249   12.49099  Entire home/apt
# 12362  45145766               Østerbro  55.73219   12.57918  Entire home/apt
# 12415  53292993                  Valby  55.64225   12.48452  Entire home/apt
# 12420   6933496               Østerbro  55.73271   12.55560  Entire home/apt
#
# ...
