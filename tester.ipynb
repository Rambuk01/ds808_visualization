# %%
import pandas as pd

# %%
data = pd.read_csv('archive/listings.csv', sep=',', encoding='utf-8')

# %%
data
# Out:
#                        id                                      listing_url  \
# 0                    6983                https://www.airbnb.com/rooms/6983
# 1                   26057               https://www.airbnb.com/rooms/26057
# 2                   26473               https://www.airbnb.com/rooms/26473
# 3                   29118               https://www.airbnb.com/rooms/29118
# 4                  670820              https://www.airbnb.com/rooms/670820
# ...                   ...                                              ...
# 12490            35292340            https://www.airbnb.com/rooms/35292340
# 12491  591033498117946366  https://www.airbnb.com/rooms/591033498117946366
# 12492             9872599             https://www.airbnb.com/rooms/9872599
# 12493  595224605480025818  https://www.airbnb.com/rooms/595224605480025818
# 12494             4806059             https://www.airbnb.com/rooms/4806059
#
#             scrape_id last_scraped  \
# 0      20220624204326   2022-06-25
# 1      20220624204326   2022-06-25
# 2      20220624204326   2022-06-25
# 3      20220624204326   2022-06-25
# 4      20220624204326   2022-06-25
# ...               ...          ...
# 12490  20220624204326   2022-06-24
# 12491  20220624204326   2022-06-24
# 12492  20220624204326   2022-06-24
# 12493  20220624204326   2022-06-24
# 12494  20220624204326   2022-06-24
#
#                                                     name  \
# 0                                   Copenhagen 'N Livin'
# 1                    Lovely house - most attractive area
# 2              City Centre Townhouse Sleeps 1-10 persons
# 3                        Best Location in Cool Istedgade
# 4                    1 Bedroom Apartment 5 min to Centre
# ...                                                  ...
# 12490              Familievenlig lejlighed nær københavn
# 12491          Bright house 25 min to Copenhagen central
# 12492  Super Juli discount: Nice house, central and calm
# 12493    Villa, 1936 with private garden near Copenhagen
# 12494                             Cosy and spacious home
#
#                                              description  \
# 0      Lovely apartment located in the hip Nørrebro a...
# 1      Our lovely house in the center of the city is ...
# 2      GUESTHOUSE ON KNABROSTRÆDE - located in the ab...
# 3      <b>The space</b><br />The apartment is situate...
# 4      The flat is located close to the city center -...
# ...                                                  ...
# 12490  Lys 4 værelses lejlighed på 89km2.  <br />3 so...
# 12491  My girlfriend and i are renting out our house ...
# 12492  Classic 3-storey villa with stucco ceilings, o...
# 12493  Villa near Copenhagen 15 minute transport from...
# 12494  20 minutes by public transport or by bike to t...
#
#                                    neighborhood_overview  \
# 0      Nice bars and cozy cafes just minutes away, ye...
# 1      The neighborhood is the most famous one and th...
# 2                                                    NaN
# 3                                                    NaN
# 4      The flat is surrounded by parks and streets th...
# ...                                                  ...
# 12490  Dyrehavsbakken, hareskoven og Københavns centr...
# 12491  5 minute walk from the house there is a park l...
# 12492  Attractive, cozy and peaceful child-friendly r...
# 12493                                                NaN
# 12494  Nice homes, green gardens, play grounds, easy ...
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/42044170/f63c...      16774
# 1      https://a0.muscache.com/pictures/miso/Hosting-...     109777
# 2      https://a0.muscache.com/pictures/8e132ba0-b68c...     112210
# 3      https://a0.muscache.com/pictures/b83c7003-367a...     125230
# 4      https://a0.muscache.com/pictures/91442571/8563...    1566921
# ...                                                  ...        ...
# 12490  https://a0.muscache.com/pictures/9e88c1f6-fead...  265718685
# 12491  https://a0.muscache.com/pictures/f343c2a1-6f3f...   88185300
# 12492  https://a0.muscache.com/pictures/9dad8dc6-7ae9...   31894497
# 12493  https://a0.muscache.com/pictures/miso/Hosting-...  452197516
# 12494  https://a0.muscache.com/pictures/0b7d18a5-7bcc...   11514806
#
#                                           host_url  ...  \
# 0          https://www.airbnb.com/users/show/16774  ...
# 1         https://www.airbnb.com/users/show/109777  ...
# 2         https://www.airbnb.com/users/show/112210  ...
# 3         https://www.airbnb.com/users/show/125230  ...
# 4        https://www.airbnb.com/users/show/1566921  ...
# ...                                            ...  ...
# 12490  https://www.airbnb.com/users/show/265718685  ...
# 12491   https://www.airbnb.com/users/show/88185300  ...
# 12492   https://www.airbnb.com/users/show/31894497  ...
# 12493  https://www.airbnb.com/users/show/452197516  ...
# 12494   https://www.airbnb.com/users/show/11514806  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.89                   4.72                4.70
# 1                            4.85                   4.94                4.81
# 2                            4.69                   4.88                4.60
# 3                            5.00                   4.85                4.77
# 4                            4.88                   4.88                4.25
# ...                           ...                    ...                 ...
# 12490                        4.90                   4.50                4.70
# 12491                         NaN                    NaN                 NaN
# 12492                        4.92                   4.92                4.92
# 12493                         NaN                    NaN                 NaN
# 12494                        4.96                   4.77                4.77
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN                f                              1
# 1         NaN                f                              1
# 2         NaN                f                             11
# 3         NaN                f                              1
# 4         NaN                f                              1
# ...       ...              ...                            ...
# 12490     NaN                f                              1
# 12491     NaN                f                              1
# 12492     NaN                f                              1
# 12493     NaN                t                              1
# 12494     NaN                t                              1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               1
# 2                                               6
# 3                                               1
# 4                                               1
# ...                                           ...
# 12490                                           1
# 12491                                           1
# 12492                                           1
# 12493                                           1
# 12494                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                5
# 3                                                0
# 4                                                0
# ...                                            ...
# 12490                                            0
# 12491                                            0
# 12492                                            0
# 12493                                            0
# 12494                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              1.10
# 1                                               0              0.56
# 2                                               0              2.06
# 3                                               0              0.15
# 4                                               0              0.10
# ...                                           ...               ...
# 12490                                           0              0.27
# 12491                                           0               NaN
# 12492                                           0              0.20
# 12493                                           0               NaN
# 12494                                           0              0.36
#
# [12495 rows x 74 columns]

# %%
data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
data[['host_is_superhost']]
# Out:
#       host_is_superhost
# 0                     f
# 1                     f
# 2                     f
# 3                     f
# 4                     f
# ...                 ...
# 12490                 t
# 12491                 f
# 12492                 f
# 12493                 f
# 12494                 f
#
# [12495 rows x 1 columns]

# %%
listing_columns = [
    
    'id',
    # 'listing_url',
    # 'scrape_id',
    # 'last_scraped',
    # 'name', # This would be connected to the 'Lookup' action. We decided not to focus on this.
    # 'description', # NLP
    # 'neighborhood_overview', # NLP
    # 'picture_url',
    
    # host
    
    # 'host_id',
    # 'host_name',
    
    #'host_url',
    #'host_since',
    #'host_location',
    #'host_about',

    # 'host_response_time',
    # 'host_response_rate',
    # 'host_acceptance_rate',
    # 'host_is_superhost',

    #'host_thumbnail_url',
    #'host_picture_url',
    'host_neighbourhood', 
    #'host_listings_count',
    #'host_total_listings_count', 
    #'host_verifications',
    #'host_has_profile_pic',
    #'host_identity_verified',
    
    #'neighbourhood',
    #'neighbourhood_cleansed', 
    #'neighbourhood_group_cleansed', 
    
    'latitude',
    'longitude',
    
    # property
    # 'property_type',
    'room_type',
    'accommodates',
    #'bathrooms', # we need to populate this
    'bathrooms_text', # get unique values, and turn it into bathrooms
    'bedrooms',
    'beds', # do we keep this?
    # 'amenities', # Wordcloud!
    'price', # per night... probably goes lower, if people rent for a week or more.
    #'minimum_nights', 
    #'maximum_nights', 
    #'minimum_minimum_nights',
    #'maximum_minimum_nights', 
    #'minimum_maximum_nights',
    #'maximum_maximum_nights',
    #'minimum_nights_avg_ntm',
    #'maximum_nights_avg_ntm', 
    #'calendar_updated', 
    #'has_availability',
    #'availability_30', # has availability for the next 30 days.
    #'availability_60', 
    #'availability_90',
    #'availability_365',
    #'calendar_last_scraped', # Need to check, if there are some low ones.
    #'number_of_reviews',
    #'number_of_reviews_ltm', #last twelve months
    #'number_of_reviews_l30d', # last 30 days
    
    #'first_review',
    #'last_review',

    # REVIEWS
    #'review_scores_rating',
    #'review_scores_accuracy',
    #'review_scores_cleanliness', 
    #'review_scores_checkin',
    #'review_scores_communication', 
    #'review_scores_location',
    #'review_scores_value', 

    # 'license', # most are empty...
    # 'instant_bookable',
    # 'calculated_host_listings_count',
    # 'calculated_host_listings_count_entire_homes',
    # 'calculated_host_listings_count_private_rooms',
    # 'calculated_host_listings_count_shared_rooms', 
    # 'reviews_per_month'
]
